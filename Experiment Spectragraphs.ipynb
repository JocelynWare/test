# %%
from astropy.io import fits
import glob

import numpy as np
np.version.version
from matplotlib import pyplot as plt
# %matplotlib inline

import scipy.ndimage

import matplotlib as mpl
mpl.colors
mpl.colors.PowerNorm

# !dir C:\Users\gabiq\Documents\2018 SEM2\ASTR278\astr-278-2018-lab-3-spectrographs-CameronFurlong\Spectragraph
# Out:
# The system cannot find the path specified.

# %% [markdown]
# ## Sodium Lamp

# %%
h = fits.open('C:\\Users\\gabiq\\Documents\\2018 SEM2\\ASTR278\\astr-278-2018-lab-3-spectrographs-CameronFurlong\\Spectragraph\\Na_ASICAP_2018-09-05_11_44_46_012.FIT')
h
Na_Spec = h[0].data

# %%
zMin = np.nanmin(Na_Spec)
zMax = np.nanmax(Na_Spec)
zStd = np.nanstd(Na_Spec)

print(zMin, zMax, zStd*3)

# Define a normaliser object
#norm = mpl.colors.PowerNorm(0.5, vmin=zMin, vmax=zStd*3)

rot_Na_Spec = scipy.ndimage.rotate(Na_Spec,4)
plt.imshow(rot_Na_Spec, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
#plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Sodium Spectra')
plt.savefig("Sodium spec rotated.png")
# Out:
# 128 64176 1794.0780254999788

# %%
norm = mpl.colors.PowerNorm

# %%
norm = mpl.colors.Normalize

# %%
np.mean(Na_Spec)
# Out:
# 835.8472655029678

# %%
maxY=1970
minY=1940
minX=650
maxX=2150
Cut = rot_Na_Spec[minY:maxY, minX:maxX]

plt.imshow(Cut, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
# plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Na Spectra')
plt.savefig("NaSpecRotAndCut.png")

# %%
cutAvg=np.nanmax(Cut, axis=0)
plt.plot(cutAvg)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Science Spectra')
plt.savefig("AverageNotCorrectedNaSpec.png")

# %%
maxY=2270
minY=2240
minX=650
maxX=2150
topCut = rot_Na_Spec[minY:maxY, minX:maxX]

plt.imshow(topCut, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
# plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('top')
plt.savefig("topCutNa.png")

# %%
maxY=1670
minY=1640
minX=650
maxX=2150
bottomCut = rot_Na_Spec[minY:maxY, minX:maxX]

plt.imshow(bottomCut, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
#plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('bottom')
plt.savefig("bottomCutNaSpec.png")

# %%
TopAvg=np.nanmean(topCut, axis=0)
BottAvg=np.nanmean(bottomCut, axis=0)
plt.plot(TopAvg)
plt.plot(BottAvg)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Combined Sky Spectra')
plt.savefig("topBottomSkyNaSpec.png")

# %%
TotAvg=(TopAvg+BottAvg)/2.
plt.plot(TotAvg)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Average Sky Spectra')
plt.savefig("AvSkyNaSpec.png")

# %%
plt.plot(cutAvg)
plt.plot(TotAvg)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Combined Sky/Science Spectra')
plt.savefig("CombinedNaSpecAndSky.png")

# %%
finalSpec = cutAvg - TotAvg
plt.plot(finalSpec)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Final Spectra')
plt.savefig("FinalNaSpec.png")

# %% [markdown]
# ## White Light

# %%
h = fits.open('C:\\Users\\gabiq\\Documents\\2018 SEM2\\ASTR278\\astr-278-2018-lab-3-spectrographs-CameronFurlong\\Spectragraph\\Mono_ASICAP_2018-09-05_11_45_46_835.FIT')
h
Mono_Spec = h[0].data

# %%
zMin = np.nanmin(Mono_Spec)
zMax = np.nanmax(Mono_Spec)
zStd = np.nanstd(Mono_Spec)

print(zMin, zMax, zStd*3)

# Define a normaliser object
#norm = mpl.colors.PowerNorm(0.5, vmin=zMin, vmax=zStd*3)

rot_Mono_Spec = scipy.ndimage.rotate(Mono_Spec,4)
plt.imshow(rot_Mono_Spec, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
#plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('White Light Spectra')
plt.savefig("WhiteSpecRot.png")
# Out:
# 16 65504 7414.146932950398

# %%
norm = mpl.colors.PowerNorm

# %%
norm = mpl.colors.Normalize

# %%
np.mean(Mono_Spec)
# Out:
# 334.0115383864417

# %%
maxY=1970
minY=1940
minX=750
maxX=2900
Cut1 = rot_Mono_Spec[minY:maxY, minX:maxX]

plt.imshow(Cut1, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
# plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Mono Light Spectra')
plt.savefig("WhiteSpecCut.png")

# %%
cutAvg1=np.nanmax(Cut1, axis=0)
plt.plot(cutAvg1)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Science Spectra')
plt.savefig("WhiteSpecNotCorrected.png")

# %%
maxY=2270
minY=2240
minX=750
maxX=2900
topCut1 = rot_Mono_Spec[minY:maxY, minX:maxX]

plt.imshow(topCut1, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
# plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('top')
plt.savefig("WhiteTopCut.png")

# %%
maxY=1670
minY=1640
minX=750
maxX=2900
bottomCut1 = rot_Mono_Spec[minY:maxY, minX:maxX]

plt.imshow(bottomCut1, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
#plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('bottom')
plt.savefig("WhiteBottomCut.png")

# %%
TopAvg1=np.nanmean(topCut1, axis=0)
BottAvg1=np.nanmean(bottomCut1, axis=0)
plt.plot(TopAvg1)
plt.plot(BottAvg1)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Combined Sky Spectra')
plt.savefig("WhiteCombinedSkySpec.png")

# %%
TotAvg1=(TopAvg1+BottAvg1)/2.
plt.plot(TotAvg1)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Average Sky Spectra')
plt.savefig("WhiteTotAvSpec.png")

# %%
plt.plot(cutAvg1)
plt.plot(TotAvg1)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Combined Sky/Science Spectra')
plt.savefig("WhiteSpecAndSky.png")

# %%
finalSpec = cutAvg1 - TotAvg1
plt.plot(finalSpec)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Final Spectra')
plt.savefig("FinalWhiteSpec.png")

# %% [markdown]
# ## Mercury Lamp

# %%
h = fits.open('')
h
Hg_Spec = h[0].data
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-28-ed4fcca4f3a0> in <module>()
# ----> 1 h = fits.open('')
#       2 h
#       3 Hg_Spec = h[0].data
#
# ~\Anaconda3\lib\site-packages\astropy\io\fits\hdu\hdulist.py in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, **kwargs)
#     159
#     160     if not name:
# --> 161         raise ValueError('Empty filename: {!r}'.format(name))
#     162
#     163     return HDUList.fromfile(name, mode, memmap, save_backup, cache,
#
# ValueError: Empty filename: ''

# %%
zMin = np.nanmin(Hg_Spec)
zMax = np.nanmax(Hg_Spec)
zStd = np.nanstd(Hg_Spec)

print(zMin, zMax, zStd*3)

# Define a normaliser object
norm = mpl.colors.PowerNorm(0.5, vmin=zMin, vmax=zStd*3)


plt.imshow(Hg_Spec, cmap='magma', aspect='equal', interpolation='none', norm=norm)
plt.colorbar()
#plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Mercury Spectra')

# %%
norm = mpl.colors.PowerNorm

# %%
norm = mpl.colors.Normalize

# %%
np.mean(Hg_Spec)

# %%
plt.plot(Hg_Spec)
plt.xlabel ('Wavelength (nm)')
plt.ylabel ('Insensity (ADUs)')
plt.suptitle ('Science Spectra')
