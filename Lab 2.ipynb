# %%
from astropy.io import fits
import glob

import numpy as np
np.version.version
from matplotlib import pyplot as plt
# %matplotlib inline

# !dir C:\Users\45155348\Desktop\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\Biases

#fits.info('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\Biases\\ASICAP_2018-08-15_10_03_46_742.FIT')

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Biases\\ASICAP_2018-08-15_10_03_46_742.FIT')
h
mydata = h[0].data
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1AED-F652
#
#  Directory of C:\Users\45155348\Desktop\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\Biases
#
# 15/08/2018  10:29 AM    <DIR>          .
# 15/08/2018  10:29 AM    <DIR>          ..
# 15/08/2018  10:03 AM        32,783,040 ASICAP_2018-08-15_10_03_46_742.FIT
# 15/08/2018  10:28 AM        32,783,040 ASICAP_2018-08-15_10_28_33_183.FIT
# 15/08/2018  10:28 AM        32,783,040 ASICAP_2018-08-15_10_28_33_506.FIT
# 15/08/2018  10:28 AM        32,783,040 ASICAP_2018-08-15_10_28_35_563.FIT
# 15/08/2018  10:28 AM        32,783,040 ASICAP_2018-08-15_10_28_37_616.FIT
#                5 File(s)    163,915,200 bytes
#                2 Dir(s)  311,608,147,968 bytes free

# %%
plt.imshow(mydata, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Original Image')
# Out:
# Text(0.5,1,u'Original Image')

# %%
np.std(mydata)
# Out:
# 12.223504184050519

# %%
np.mean(mydata)
# Out:
# 119.37437031396439

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Biases\\ASICAP_2018-08-15_10_28_33_183.FIT')
h
bias2 = h[0].data
plt.imshow(bias2, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Bias2')
print(np.std(bias2))
print(np.mean(bias2))
# Out:
# 12.244293285425117
# 119.29338390346767

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Biases\\ASICAP_2018-08-15_10_28_33_506.FIT')
h
bias3 = h[0].data
plt.imshow(bias3, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Bias3')
np.sqrt(np.mean(bias3**2))
print(np.std(bias3))
print(np.mean(bias3))
# Out:
# 12.24422061596109
# 119.29768626991566

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Biases\\ASICAP_2018-08-15_10_28_35_563.FIT')
h
bias4 = h[0].data
plt.imshow(bias4, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Bias4')
print(np.std(bias4))
print(np.mean(bias4))
# Out:
# 12.24800908535528
# 119.29210695876289

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Biases\\ASICAP_2018-08-15_10_28_37_616.FIT')
h
bias5 = h[0].data
plt.imshow(bias5, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(3354,2529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Bias5')
print(np.std(bias5))
print(np.mean(bias5))
# Out:
# 12.245708908796402
# 119.28616447985004

# %%
# !dir C:\Users\45155348\Desktop\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\Bad_Pixel
    
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Bad_Pixel\\ASICAP_2018-08-15_10_43_12_797.FIT')
h
bad1 = h[0].data
plt.imshow(bad1, cmap='magma', aspect='equal', interpolation='none')
plt.colorbar()
plt.clim(6354,42529) #adjust this to set the upper and lower range of the colorbar
plt.gcf().set_size_inches(20,12)
plt.title('Bad1')
# Out:
#  Volume in drive C is Windows
#  Volume Serial Number is 1AED-F652
#
#  Directory of C:\Users\45155348\Desktop\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\Bad_Pixel
#
# 15/08/2018  10:45 AM    <DIR>          .
# 15/08/2018  10:45 AM    <DIR>          ..
# 15/08/2018  10:43 AM        32,783,040 ASICAP_2018-08-15_10_43_12_797.FIT
# 15/08/2018  10:44 AM        32,783,040 ASICAP_2018-08-15_10_44_11_723.FIT
#                2 File(s)     65,566,080 bytes
#                2 Dir(s)  311,608,123,392 bytes free
# Text(0.5,1,u'Bad1')

# %%
plt.hist(bad1.flatten(),100)
# Out:
# (array([5.000000e+00, 7.000000e+00, 2.900000e+01, 4.300000e+01,
#         1.530000e+02, 2.550000e+02, 5.890000e+02, 9.010000e+02,
#         1.734000e+03, 2.102000e+03, 3.754000e+03, 4.149000e+03,
#         6.871000e+03, 7.117000e+03, 1.173000e+04, 1.209300e+04,
#         1.961700e+04, 1.953900e+04, 3.123200e+04, 3.102700e+04,
#         1.90748e+05, 1.53604e+05, 1.21430e+05, 9.50330e+04, 7.33210e+04,
# ...

# %%
plt.hist(division[division<0.22],100)

np.sum(division<0.215)
# Out:
# 15

# %%
plt.hist(division[division>0.255], 100)


np.sum(division>0.261)
# Out:
# 11

# %%
bad1.size
# Out:
# 16389120

# %%
26/(bad1.size*1.0)
# Out:
# 1.5864183067791315e-06

# %%
# h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_23_673.FIT')
h
Lin1 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_29_000.FIT')
h
Lin2 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_34_698.FIT')
h
Lin3 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_39_819.FIT')
h
Lin4 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_44_980.FIT')
h
Lin5 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_49_850.FIT')
h
Lin6 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_54_385.FIT')
h
Lin7 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_39_59_282.FIT')
h
Lin8 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_40_04_994.FIT')
h
Lin9 = h[0].data
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Linearity\\ASICAP_2018-08-22_09_40_09_098.FIT')
h
Lin10 = h[0].data

# %%
Pixel_Value=np.array([np.mean(Lin2),np.mean(Lin3),np.mean(Lin4),np.mean(Lin5),np.mean(Lin6),np.mean(Lin7),np.mean(Lin8),np.mean(Lin9),np.mean(Lin10)])

# %%
plt.plot(Pixel_Value)

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(No Lens)\\ASICAP_2018-08-22_10_23_45_646.FIT')
h
FFNL1 = h[0].data

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(No Lens)\\ASICAP_2018-08-22_10_23_50_686.FIT')
h
FFNL2 = h[0].data

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(No Lens)\\ASICAP_2018-08-22_10_24_00_934.FIT')
h
FFNL3 = h[0].data

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(With Lens)\\ASICAP_2018-08-22_10_28_51_098.FIT')
h
FFWL1 = h[0].data

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(With Lens)\\ASICAP_2018-08-22_10_28_53_305.FIT')
h
FFWL2 = h[0].data

h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(With Lens)\\ASICAP_2018-08-22_10_28_56_291.FIT')
h
FFWL3 = h[0].data

# %%
plt.hist(FFNL1.flatten(),100)
# Out:
# (array([9.20000e+01, 1.76000e+03, 1.10300e+04, 2.87320e+04, 5.06520e+04,
#         7.05010e+04, 1.00060e+05, 1.28170e+05, 1.72634e+05, 2.10437e+05,
#         2.75273e+05, 3.22448e+05, 4.06066e+05, 4.75449e+05, 5.88687e+05,
#         6.43624e+05, 7.28068e+05, 7.30474e+05, 7.82463e+05, 7.72184e+05,
#         8.24826e+05, 7.97412e+05, 8.24711e+05, 7.71993e+05, 7.81583e+05,
#         7.33940e+05, 7.50218e+05, 6.96636e+05, 7.05765e+05, 6.73281e+05,
#         6.92640e+05, 6.35213e+05, 5.49368e+05, 3.17359e+05, 1.17734e+05,
#         1.66760e+04, 9.18000e+02, 1.90000e+01, 6.00000e+00, 3.00000e+00,
#         0.00000e+00, 5.00000e+00, 1.00000e+00, 1.00000e+00, 2.00000e+00,
#         1.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 1.00000e+00,
#         1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
# ...

# %%
plt.hist(FFNL2.flatten(),100)
# Out:
# (array([2.50000e+01, 7.67000e+02, 7.02400e+03, 2.16090e+04, 4.19540e+04,
#         6.14430e+04, 8.91830e+04, 1.14225e+05, 1.56205e+05, 1.91541e+05,
#         2.51095e+05, 2.92306e+05, 3.66884e+05, 4.31708e+05, 5.40803e+05,
#         5.97947e+05, 6.87925e+05, 7.08443e+05, 7.62524e+05, 7.47362e+05,
#         8.04405e+05, 7.88371e+05, 8.15170e+05, 7.63409e+05, 7.46459e+05,
#         7.64387e+05, 7.16094e+05, 7.19698e+05, 6.75043e+05, 6.94553e+05,
#         6.59614e+05, 6.72658e+05, 6.11610e+05, 5.06937e+05, 2.74284e+05,
#         9.27570e+04, 1.20540e+04, 6.15000e+02, 9.00000e+00, 5.00000e+00,
#         1.00000e+00, 3.00000e+00, 3.00000e+00, 0.00000e+00, 3.00000e+00,
#         2.00000e+00, 0.00000e+00, 1.00000e+00, 1.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
# ...

# %%
#         4.36358e+05, 4.38228e+05, 4.30760e+05, 3.87315e+05, 4.05886e+05,
# ...

# %%
plt.hist(FFWL3.flatten(),100)
# Out:
# (array([1.70000e+01, 1.18000e+02, 4.66000e+02, 1.54400e+03, 3.49400e+03,
#         7.44600e+03, 1.18570e+04, 1.95590e+04, 2.47270e+04, 3.55370e+04,
#         4.08040e+04, 5.30300e+04, 5.70390e+04, 7.17510e+04, 7.46410e+04,
#         9.29620e+04, 9.77030e+04, 1.20632e+05, 1.22962e+05, 1.45036e+05,
#         1.41014e+05, 1.58092e+05, 1.49024e+05, 1.62654e+05, 1.52227e+05,
#         1.67258e+05, 1.69754e+05, 1.60585e+05, 1.77383e+05, 1.69803e+05,
#         1.90594e+05, 1.83796e+05, 2.10311e+05, 2.06431e+05, 2.39505e+05,
#         2.36626e+05, 2.73312e+05, 2.70440e+05, 3.08921e+05, 3.01703e+05,
#         3.40915e+05, 3.27247e+05, 3.66470e+05, 3.46748e+05, 3.80453e+05,
#         3.50963e+05, 3.77249e+05, 3.46550e+05, 3.71278e+05, 3.40103e+05,
#         3.67066e+05, 3.65208e+05, 3.38994e+05, 3.68399e+05, 3.42069e+05,
#         3.75298e+05, 3.52909e+05, 3.96625e+05, 3.75283e+05, 4.23282e+05,
#         4.02249e+05, 4.42093e+05, 4.07841e+05, 4.34314e+05, 3.89656e+05,
# ...

# %%
h = fits.open('C:\\Users\\45155348\\Desktop\\astr-278-2018-lab-2-image-sensors-GabriellaQuattropani\\Flat-Field-(No Lens)\\ASICAP_2018-08-22_10_23_45_646.FIT')
h
Cut = h[0].data
maxY=2258
minY=1181 
minX=1140
maxX=3057
newCut = Cut[minY:maxY, minX:maxX]

# %%
# Out:
# (219504L,)

# %%
plt.imshow(newCut)

# %%
CutnoBias = newCut-119.3 
print(CutnoBias)
# Out:
# [[25224.7 24552.7 25176.7 ... 26120.7 25464.7 25784.7]
#  [24552.7 25160.7 24440.7 ... 25784.7 25912.7 25304.7]
#  [24824.7 24808.7 24872.7 ... 25976.7 25640.7 26184.7]
#  ...
#  [26232.7 25720.7 26344.7 ... 27768.7 27272.7 27624.7]
#  [25576.7 26120.7 26648.7 ... 26968.7 27128.7 26712.7]
#  [26472.7 25752.7 26264.7 ... 27176.7 26936.7 27336.7]]

# %%
plt.hist(CutnoBias.flatten(),100)
# Out:
# (array([1.00000e+00, 0.00000e+00, 0.00000e+00, 5.00000e+00, 1.80000e+01,
#         4.90000e+01, 1.26000e+02, 2.49000e+02, 4.88000e+02, 7.42000e+02,
#         1.25800e+03, 1.83500e+03, 2.69000e+03, 3.72200e+03, 5.04400e+03,
#         6.65300e+03, 8.53300e+03, 1.09940e+04, 1.39010e+04, 1.77220e+04,
#         2.22240e+04, 2.75660e+04, 3.39780e+04, 4.08600e+04, 4.09670e+04,
#         5.49250e+04, 6.32410e+04, 7.15650e+04, 7.95880e+04, 8.63300e+04,
#         9.31680e+04, 9.99150e+04, 1.05373e+05, 1.10774e+05, 1.13846e+05,
#         1.17032e+05, 1.18239e+05, 1.16620e+05, 1.10518e+05, 1.02205e+05,
#         9.08050e+04, 7.88320e+04, 6.45290e+04, 5.04860e+04, 3.72650e+04,
#         2.55270e+04, 1.63840e+04, 9.15100e+03, 4.81900e+03, 2.07500e+03,
#         1.09500e+03, 4.54000e+02, 1.51000e+02, 4.20000e+01, 1.50000e+01,
#         7.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
#         0.00000e+00, 1.00000e+00, 0.00000e+00, 0.00000e+00, 0.00000e+00,
# ...
